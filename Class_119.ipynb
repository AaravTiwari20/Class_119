# %% [markdown]
# <a href="https://colab.research.google.com/github/AaravTiwari20/Class_119/blob/main/Class_119.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
files_to_load = files.upload()
# Out:
#      <input type="file" id="files-52023a50-37a1-471c-879c-38a87b966f1e" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-52023a50-37a1-471c-879c-38a87b966f1e">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script src="/nbextensions/google.colab/files.js"></script>
# Saving diabetes.csv to diabetes.csv

# %%
import pandas as pd

column_names = ["pregnant","glucose","bp","skin","insulin","bmi","pedigree","age","label"]

df = pd.read_csv("diabetes.csv",names = column_names).iloc[1:]

print(df.head())
# Out:
#   pregnant glucose  bp skin insulin   bmi pedigree age label
# 1        6     148  72   35       0  33.6    0.627  50     1
# 2        1      85  66   29       0  26.6    0.351  31     0
# 3        8     183  64    0       0  23.3    0.672  32     1
# 4        1      89  66   23      94  28.1    0.167  21     0
# 5        0     137  40   35     168  43.1    2.288  33     1

# %%
from sklearn.tree import DecisionTreeClassifier
from sklearn.model_selection import train_test_split
from sklearn import metrics

features = ["pregnant","glucose","bp","skin","insulin","bmi","pedigree","age"]

X = df[features]
Y = df.label

X_train,X_test,Y_train,Y_test = train_test_split(X,Y,test_size = 0.3,random_state = 1)

clf = DecisionTreeClassifier(max_depth = 5)
clf = clf.fit(X_train,Y_train)

Y_Pred = clf.predict(X_test)

print("Accuracy",metrics.accuracy_score(Y_test,Y_Pred))
# Out:
# Accuracy 0.7705627705627706

# %%
from sklearn.tree import export_graphviz
from six import StringIO
from IPython.display import Image
import pydotplus

dot_data = StringIO()

export_graphviz(clf,out_file = dot_data, filled = True,rounded = True,special_characters = True,
                feature_names = features,class_names = ["0","1"])

print(dot_data.getvalue())
# Out:
# digraph Tree {
# node [shape=box, style="filled, rounded", color="black", fontname="helvetica"] ;
# edge [fontname="helvetica"] ;
# 0 [label=<glucose &le; 129.5<br/>gini = 0.449<br/>samples = 537<br/>value = [354, 183]<br/>class = 0>, fillcolor="#f2c29f"] ;
# 1 [label=<bmi &le; 26.3<br/>gini = 0.329<br/>samples = 357<br/>value = [283, 74]<br/>class = 0>, fillcolor="#eca26d"] ;
# 0 -> 1 [labeldistance=2.5, labelangle=45, headlabel="True"] ;
# 2 [label=<bmi &le; 9.1<br/>gini = 0.06<br/>samples = 97<br/>value = [94, 3]<br/>class = 0>, fillcolor="#e6853f"] ;
# 1 -> 2 ;
# 3 [label=<age &le; 28.0<br/>gini = 0.444<br/>samples = 6<br/>value = [4, 2]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 2 -> 3 ;
# 4 [label=<gini = 0.0<br/>samples = 4<br/>value = [4, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 3 -> 4 ;
# 5 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 3 -> 5 ;
# 6 [label=<pedigree &le; 0.669<br/>gini = 0.022<br/>samples = 91<br/>value = [90, 1]<br/>class = 0>, fillcolor="#e5823b"] ;
# 2 -> 6 ;
# 7 [label=<gini = 0.0<br/>samples = 76<br/>value = [76, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 6 -> 7 ;
# 8 [label=<pedigree &le; 0.705<br/>gini = 0.124<br/>samples = 15<br/>value = [14, 1]<br/>class = 0>, fillcolor="#e78a47"] ;
# 6 -> 8 ;
# 9 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 8 -> 9 ;
# 10 [label=<gini = 0.0<br/>samples = 14<br/>value = [14, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 8 -> 10 ;
# 11 [label=<age &le; 27.5<br/>gini = 0.397<br/>samples = 260<br/>value = [189, 71]<br/>class = 0>, fillcolor="#efb083"] ;
# 1 -> 11 ;
# 12 [label=<bmi &le; 45.4<br/>gini = 0.243<br/>samples = 120<br/>value = [103, 17]<br/>class = 0>, fillcolor="#e9965a"] ;
# 11 -> 12 ;
# 13 [label=<pregnant &le; 7.0<br/>gini = 0.212<br/>samples = 116<br/>value = [102, 14]<br/>class = 0>, fillcolor="#e99254"] ;
# 12 -> 13 ;
# 14 [label=<gini = 0.201<br/>samples = 115<br/>value = [102, 13]<br/>class = 0>, fillcolor="#e89152"] ;
# 13 -> 14 ;
# 15 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 13 -> 15 ;
# 16 [label=<skin &le; 35.5<br/>gini = 0.375<br/>samples = 4<br/>value = [1, 3]<br/>class = 1>, fillcolor="#7bbeee"] ;
# 12 -> 16 ;
# 17 [label=<gini = 0.0<br/>samples = 1<br/>value = [1, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 16 -> 17 ;
# 18 [label=<gini = 0.0<br/>samples = 3<br/>value = [0, 3]<br/>class = 1>, fillcolor="#399de5"] ;
# 16 -> 18 ;
# 19 [label=<pedigree &le; 0.563<br/>gini = 0.474<br/>samples = 140<br/>value = [86, 54]<br/>class = 0>, fillcolor="#f5d0b5"] ;
# 11 -> 19 ;
# 20 [label=<glucose &le; 101.5<br/>gini = 0.408<br/>samples = 98<br/>value = [70, 28]<br/>class = 0>, fillcolor="#efb388"] ;
# 19 -> 20 ;
# 21 [label=<gini = 0.208<br/>samples = 34<br/>value = [30, 4]<br/>class = 0>, fillcolor="#e89253"] ;
# 20 -> 21 ;
# 22 [label=<gini = 0.469<br/>samples = 64<br/>value = [40, 24]<br/>class = 0>, fillcolor="#f5cdb0"] ;
# 20 -> 22 ;
# 23 [label=<pregnant &le; 8.5<br/>gini = 0.472<br/>samples = 42<br/>value = [16, 26]<br/>class = 1>, fillcolor="#b3d9f5"] ;
# 19 -> 23 ;
# 24 [label=<gini = 0.5<br/>samples = 33<br/>value = [16, 17]<br/>class = 1>, fillcolor="#f3f9fd"] ;
# 23 -> 24 ;
# 25 [label=<gini = 0.0<br/>samples = 9<br/>value = [0, 9]<br/>class = 1>, fillcolor="#399de5"] ;
# 23 -> 25 ;
# 26 [label=<bmi &le; 27.85<br/>gini = 0.478<br/>samples = 180<br/>value = [71, 109]<br/>class = 1>, fillcolor="#baddf6"] ;
# 0 -> 26 [labeldistance=2.5, labelangle=-45, headlabel="False"] ;
# 27 [label=<glucose &le; 145.5<br/>gini = 0.375<br/>samples = 36<br/>value = [27, 9]<br/>class = 0>, fillcolor="#eeab7b"] ;
# 26 -> 27 ;
# 28 [label=<age &le; 59.5<br/>gini = 0.1<br/>samples = 19<br/>value = [18, 1]<br/>class = 0>, fillcolor="#e68844"] ;
# 27 -> 28 ;
# 29 [label=<gini = 0.0<br/>samples = 16<br/>value = [16, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 28 -> 29 ;
# 30 [label=<age &le; 61.0<br/>gini = 0.444<br/>samples = 3<br/>value = [2, 1]<br/>class = 0>, fillcolor="#f2c09c"] ;
# 28 -> 30 ;
# 31 [label=<gini = 0.0<br/>samples = 1<br/>value = [0, 1]<br/>class = 1>, fillcolor="#399de5"] ;
# 30 -> 31 ;
# 32 [label=<gini = 0.0<br/>samples = 2<br/>value = [2, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 30 -> 32 ;
# 33 [label=<bmi &le; 23.1<br/>gini = 0.498<br/>samples = 17<br/>value = [9, 8]<br/>class = 0>, fillcolor="#fcf1e9"] ;
# 27 -> 33 ;
# 34 [label=<gini = 0.0<br/>samples = 3<br/>value = [3, 0]<br/>class = 0>, fillcolor="#e58139"] ;
# 33 -> 34 ;
# 35 [label=<bmi &le; 25.55<br/>gini = 0.49<br/>samples = 14<br/>value = [6, 8]<br/>class = 1>, fillcolor="#cee6f8"] ;
# 33 -> 35 ;
# 36 [label=<gini = 0.0<br/>samples = 6<br/>value = [0, 6]<br/>class = 1>, fillcolor="#399de5"] ;
# 35 -> 36 ;
# 37 [label=<gini = 0.375<br/>samples = 8<br/>value = [6, 2]<br/>class = 0>, fillcolor="#eeab7b"] ;
# 35 -> 37 ;
# 38 [label=<glucose &le; 158.5<br/>gini = 0.424<br/>samples = 144<br/>value = [44, 100]<br/>class = 1>, fillcolor="#90c8f0"] ;
# 26 -> 38 ;
# 39 [label=<age &le; 30.5<br/>gini = 0.487<br/>samples = 88<br/>value = [37, 51]<br/>class = 1>, fillcolor="#c9e4f8"] ;
# 38 -> 39 ;
# 40 [label=<bp &le; 23.0<br/>gini = 0.49<br/>samples = 42<br/>value = [24, 18]<br/>class = 0>, fillcolor="#f8e0ce"] ;
# 39 -> 40 ;
# 41 [label=<gini = 0.0<br/>samples = 4<br/>value = [0, 4]<br/>class = 1>, fillcolor="#399de5"] ;
# 40 -> 41 ;
# 42 [label=<gini = 0.465<br/>samples = 38<br/>value = [24, 14]<br/>class = 0>, fillcolor="#f4caac"] ;
# 40 -> 42 ;
# 43 [label=<bmi &le; 34.05<br/>gini = 0.405<br/>samples = 46<br/>value = [13, 33]<br/>class = 1>, fillcolor="#87c4ef"] ;
# 39 -> 43 ;
# 44 [label=<gini = 0.49<br/>samples = 21<br/>value = [9, 12]<br/>class = 1>, fillcolor="#cee6f8"] ;
# 43 -> 44 ;
# 45 [label=<gini = 0.269<br/>samples = 25<br/>value = [4, 21]<br/>class = 1>, fillcolor="#5fb0ea"] ;
# 43 -> 45 ;
# 46 [label=<pedigree &le; 1.157<br/>gini = 0.219<br/>samples = 56<br/>value = [7, 49]<br/>class = 1>, fillcolor="#55abe9"] ;
# 38 -> 46 ;
# 47 [label=<pedigree &le; 0.343<br/>gini = 0.147<br/>samples = 50<br/>value = [4, 46]<br/>class = 1>, fillcolor="#4aa6e7"] ;
# 46 -> 47 ;
# 48 [label=<gini = 0.332<br/>samples = 19<br/>value = [4, 15]<br/>class = 1>, fillcolor="#6eb7ec"] ;
# 47 -> 48 ;
# 49 [label=<gini = 0.0<br/>samples = 31<br/>value = [0, 31]<br/>class = 1>, fillcolor="#399de5"] ;
# 47 -> 49 ;
# 50 [label=<age &le; 28.0<br/>gini = 0.5<br/>samples = 6<br/>value = [3, 3]<br/>class = 0>, fillcolor="#ffffff"] ;
# 46 -> 50 ;
# 51 [label=<gini = 0.0<br/>samples = 2<br/>value = [0, 2]<br/>class = 1>, fillcolor="#399de5"] ;
# 50 -> 51 ;
# 52 [label=<gini = 0.375<br/>samples = 4<br/>value = [3, 1]<br/>class = 0>, fillcolor="#eeab7b"] ;
# 50 -> 52 ;
# }

# %%
graph = pydotplus.graph_from_dot_data(dot_data.getvalue())
graph.write_png("Diabetes.png")

Image(graph.create_png())
